# %% [markdown]
# # markdown overview
#
# ```markdown
# # Styles d'écriture Markdown
#
# ## Titres
# # Titre de niveau 1
# ## Titre de niveau 2
# ### Titre de niveau 3
# #### Titre de niveau 4
# ##### Titre de niveau 5
# ###### Titre de niveau 6
#
# ## Texte
# **Texte en gras**
#
# *Texte en italique*
#
# ~~Texte barré~~
#
# **_Texte en gras et italique_**
#
# ## Listes
# ### Liste à puces
# - Élément 1
# - Élément 2
#     - Sous-élément 2.1
#     - Sous-élément 2.2
#
# ### Liste numérotée
# 1. Premier élément
# 2. Deuxième élément
#      1. Sous-élément 2.1
#      2. Sous-élément 2.2
#
# ## Citations
# > Ceci est une citation.
#
# ## Liens
# [Texte du lien](http://exemple.com)
#
# ## Images
# ![Texte alternatif](http://exemple.com/image.jpg)
#
# ## Code
# ### Code en ligne
# Voici un exemple de `code en ligne`.
#
# ### Bloc de code
# ```python
# print("Hello, world!")
# ```
#
# ## Tableaux
# | En-tête 1 | En-tête 2 |
# |-----------|-----------|
# | Cellule 1 | Cellule 2 |
# | Cellule 3 | Cellule 4 |
#
# ## Séparateurs
# ---
# ```
